# %%
from matplotlib.pyplot import scatter
from matplotlib.colors import to_rgba
import math
from numpy import arange

# %%
# Out:
# -40 25 (1.0, 0.0, 0.0)
# -50 25 (0.9800665778412416, 0.0, 0.19866933079506122)
# -58 25 (0.9210609940028851, 0.0, 0.3894183423086505)
# -62 25 (0.8253356149096782, 0.0, 0.5646424733950355)
# -60 25 (0.6967067093471654, 0.0, 0.7173560908995228)
# -48 25 (0.5403023058681398, 0.0, 0.8414709848078965)
# -23 25 (0.3623577544766734, 0.0, 0.9320390859672264)
# 12 25 (0.16996714290024081, 0.0, 0.9854497299884603)
# 56 25 (-0.029199522301288815, 0.0, 0.9995736030415051)
# 99 25 (-0.2272020946930871, 0.0, 0.9738476308781951)
# 132 25 (-0.4161468365471424, 0.0, 0.9092974268256817)
# 152 25 (-0.5885011172553458, 0.0, 0.8084964038195901)
# 161 25 (-0.7373937155412458, 0.0, 0.6754631805511506)
# 161 25 (-0.8568887533689473, 0.0, 0.5155013718214642)
# 156 25 (-0.9422223406686583, 0.0, 0.33498815015590466)
# 147 25 (-0.9899924966004454, 0.0, 0.1411200080598672)
# -56 13 (0.879923176281257, 0.29552020666133955, 0.3720255519422596)
# ...

# %%
x = []
y = []
colours = []
for c, n in zip(coords, normals):
    xp = int(WIDTH / 2 - (K1 * c[0]) / (K2 + c[2]))
    yp = int(HEIGHT / 2 - (K1 * c[1]) / (K2 + c[2]))
    
    l = (n[1] - n[2]) * 0.7
    
    x.append(xp)
    y.append(yp)
scatter(x, y)
